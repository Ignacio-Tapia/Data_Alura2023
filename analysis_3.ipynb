# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/C1/inmuebles_bogota.csv')
inmuebles #Indica las 5 1ras filas
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles.shape  #Indica la cantidad de filas y columnas
# Out:
# (9520, 8)

# %%
inmuebles.columns  #Indica los nombres de columnas
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columnas) #Renombra las columnas
inmuebles.sample(10)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8512  Apartamento       Apartamento en venta en Fontibón             2      2
# 8621  Apartamento       Apartamento en venta en Engativa             3      1
# 8415         Casa                  Casa en venta en Suba             5      3
# 5750  Apartamento  Apartamento en venta en Santa Barbara             3      2
# 2009  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 5213  Apartamento           Apartamento en venta en Suba             3      2
# 9283         Casa                  Casa en venta en Suba             8      4
# 8172  Apartamento       Apartamento en venta en Cedritos             3      4
# 2379  Apartamento        Apartamento en venta en Usaquén             3      4
# 65    Apartamento       Apartamento en venta en Fontibón             3      3
#
#       Area         Barrio                                    UPZ  \
# ...

# %%
inmuebles.info() #Muestra un resumen del data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300] #Devuelve la informacion del registro OJO empieza contando desde el n. 0
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305] #Devuelve el rango - el [n izq lo INCLUYE:n. derecha NO LO INCLUYE]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles.iloc[:305].tail() #Trae la 5 ultimas exeptuando el 305
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles.iloc[9516:].tail() #Trae la 5 ultimas exeptuando el 305
# Out:
#              Tipo                                     Descripcion  \
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 9516             2      2   100  Parque Central Bavaria
# 9517             8      6   383                Restrepo
# 9518             3      2   183                Engativa
# 9519             3      1    52                 Tintala
#
#                                          UPZ          Valor
# 9516  SANTA FE: Las Nieves + Sagrado Corazón  $ 670.000.000
# 9517                                Restrepo  $ 900.000.000
# 9518                                Engativá  $ 335.000.000
# 9519                                 Tintala  $ 144.990.000

# %%
inmuebles['Valor'][300] #Trae el dato del argumento
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean() #Indica el promedio
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100) #Trae valores ALEATORIOS
# Out:
#              Tipo                                        Descripcion  \
# 1884  Apartamento             Apartamento en venta en Barrios Unidos
# 4966  Apartamento             Apartamento en venta en Barrios Unidos
# 3589  Apartamento             Apartamento en venta en Ciudad Bolívar
# 512   Apartamento               Apartamento en venta en Gran America
# 9207  Apartamento                    Apartamento en venta en Usaquén
# ...           ...                                                ...
# 4534  Apartamento             Apartamento en venta en Barrios Unidos
# 419   Apartamento              Apartamento en venta en Santa Barbara
# 763   Apartamento                    Apartamento en venta en Usaquén
# 3157  Apartamento                   Apartamento en venta en El Chicó
# 4685         Casa  Casa en venta en Cundinamarca - Bogotá D.C. - ...
#
#       Habitaciones  Banos  Area          Barrio  \
# 1884             3      3   116  Barrios Unidos
# ...

# %%
inmuebles.Barrio == 'Chico Reservado' #Llama a la columna barrio con un Booleano y trae toda la columna comparandolo si es el dato correcto o no
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado')) #Toma como entero los valores del booleano \\ Y los 225 son REGISTROS
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico) #type devuelve conjunto
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts()) #len Devuelve la longitud de REGISTROS UNICOS de la columna de barrios q NO SE REPITE
# Out:
# 149

# %% [markdown]
# inmuebles.Barrio.value_counts() #Devuelve - serie\conjunto de registros por barrio

# %%
len(inmuebles.UPZ.value_counts()) #Trae la contida de UPZ
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts() 

inmuebles_barrio.head(4).plot.bar() #.plot creo un grafico bar es un grafico de barra
# Out:
# <Axes: >

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts() 

inmuebles_barrio.head(4).plot.bar() #.plot creo un grafico bar es un grafico de barra

espacio = inmuebles_barrio

# %%
inmuebles_barrio.head(10).plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='Barrio'>

# %%
#Desafio
#1. Promedio de årea de todos los inmuebles en los barrios en el dataset. El top 10.
#2. Consultar otros datos estadisticos, conteo, mediana, valores minimo y måximo.

# %%
inmuebles_barrio.head(10).plot.barh()
# Out:
# <Axes: >

# %%
inmuebles.Valor.min()
# Out:
# '$ 1.000.000.000'

# %%
inmuebles.Valor.head(5).max()
# Out:
# '$ 970.000.000'

# %%
inmuebles.Valor.value_counts()
# Out:
# $ 450.000.000      128
# $ 500.000.000      127
# $ 550.000.000      121
# $ 390.000.000      107
# $ 650.000.000      102
#                   ...
# $ 1.499.999.000      1
# $ 531.000.000        1
# $ 2.755.500.000      1
# $ 5.250.000.000      1
# $ 144.990.000        1
# Name: Valor, Length: 1039, dtype: int64

# %%
len(inmuebles.Valor.value_counts())
# Out:
# 1039

# %%
inmuebles_Valor = (inmuebles.Valor.value_counts())
inmuebles_Valor.head(5).plot.barh()
# Out:
# <Axes: >

# %%
inmuebles_Valor = (inmuebles.Valor.value_counts())
inmuebles_Valor.head(5).plot()
# Out:
# <Axes: >

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {'A': [1, 2, 3, 4, 5],
        'B': [6, 7, 8, 9, 10],
        'C': [11, 12, 13, 14, 15]}
df = pd.DataFrame(data)

# Obtener los valores mínimos y máximos de cada columna
min_values = df.min()
max_values = df.max()

# Mostrar los valores mínimos y máximos
print("Valores mínimos:")
print(min_values)
print("\nValores máximos:")
print(max_values)
# Out:
# Valores mínimos:
# A     1
# B     6
# C    11
# dtype: int64
#
# Valores máximos:
# A     5
# B    10
# C    15
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)
# Out:
# <BarContainer object of 4 artists>

# %%
inmuebles.sample(5)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 4234  Apartamento  Apartamento en venta en Engativa             3      2
# 7493         Casa         Casa en venta en Fontibón             2      1
# 475          Casa         Casa en venta en Engativa            10      7
# 1787  Apartamento  Apartamento en venta en Cedritos             3      2
# 6244  Apartamento  Apartamento en venta en Engativa             3      2
#
#       Area    Barrio       UPZ          Valor
# 4234    67  Engativa  Engativá  $ 256.000.000
# 7493   118  Fontibón  Fontibón  $ 130.000.000
# 475    370  Engativa  Engativá  $ 850.000.000
# 1787    97  Cedritos   Usaquén  $ 450.000.000
# 6244    61  Engativa  Engativá  $ 220.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split() #.split Separa una cadena de texto con algun parametro - () si lo dejo en blanco toma el espacio
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split() #.split = Convierte a string y esta separado con numero y signo pesos \\ sigue devolviendo en formato de serie
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
inmuebles.Valor.str.split(expand = True) #Devuelve un formato de dataframe c/ 2 columnas
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor = inmuebles.Valor.str.split(expand = True)
inmuebles['Moneda'] = valor [0]
inmuebles['Precio'] = valor [1]
inmuebles.sample(5)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 4591  Apartamento          Apartamento en venta en Kennedy             3
# 8858  Apartamento          Apartamento en venta en Kennedy             3
# 6365  Apartamento         Apartamento en venta en Cedritos             3
# 5349  Apartamento             Apartamento en venta en Bosa             3
# 2619  Apartamento  Apartamento en venta en Chico Reservado             2
#
#       Banos  Area           Barrio                                 UPZ  \
# 4591      2    57          Kennedy                     Kennedy Central
# 8858      2    60          Kennedy                     Kennedy Central
# 6365      2    85         Cedritos                             Usaquén
# 5349      2    57             Bosa                        Bosa Central
# 2619      2   108  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#               Valor Moneda       Precio
# 4591  $ 199.000.000      $  199.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# TENGO Q CAMBIAR EL PUNTO POR NADA

# %%
inmuebles['Precio'].sum() #Estooo no suma
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.0
# ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex = True) #.replace remplaza el punto por nada

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000 #astype convierte el registro en un valor numerico
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
pd.set_option('display.precision',2) #obtengo 2 decimales
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110] #.loc ubica un registro especifco
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# Histograma =  MUESTRA LA Frecuencia de una variable
# Graf. de Barra = muestra la cantidad de repeticiones de una variable

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)  #bins es un parametro y det. un rango del histograma (+bins el grafico se achica)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# La distrucion de los precios es entre 0 2millones

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6)) #figsize = det. el ancho y el alto del tamano del grafico
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde = True, hue = 'Tipo') #kde =  det una curva - densidad // hue = parametro det. otros variable
grafica.set_title('Distribucion de Valores en Bogota') #Det. titulo
plt.xlim((50,3000))# Det. 1 limite de rango en x
plt.ylim((0,100))# Det. 1 limite de rango en y
plt.savefig('/content/drive/MyDrive/Colab Notebooks/C2/Valores_Bogota4.png', format = 'png') #ValueError: Format 'xlsx' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff, webp)
plt.show()

# %%
inmuebles['Valor_m2_Millones'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millones
# 0    $ 360.000.000      $   360000000         360.00               5.14
# 1    $ 670.000.000      $   670000000         670.00               3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00               7.78

# %% [markdown]
# Calcular el promedio de precio por m2 para cada uno de los barrios

# %%
inmuebles.groupby('Barrio').mean() #Det. promedio de los registros numericos, agrupados por barrio
# Out:
# <ipython-input-139-7d7d3139a790>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean() #Det. promedio de los registros numericos, agrupados por barrio
#                     Habitaciones  Banos   Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# ...

# %% [markdown]
# Sumamos precio todos inmuebles det de un barrio  dividido / toda la superficie de un det. barrio

# %%
datos_barrios = inmuebles.groupby('Barrio').sum()
datos_barrios
# Out:
# <ipython-input-140-04ffa83d2618>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrios = inmuebles.groupby('Barrio').sum()
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# ...

# %%
datos_barrios['Valor_m2_Barrio'] = datos_barrios['Precio_Millon']/datos_barrios['Area']
datos_barrios
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millones  Valor_m2_Barrio
# Barrio
# Alameda                          5.98             5.98
# Alhambra                        73.56             3.95
# ...

# %%
m2_barrio = dict (datos_barrios['Valor_m2_Barrio']) #creo un diccionario toma como valor el nuevo precio de m2

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio) #.map sustituye el valor antiguo x el nuevo valor 
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millones  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrios.reset_index(inplace=True) #parametro inplace reasigna 
datos_barrios
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 0                 5.98             5.98
# 1                73.56             3.95
# ...

# %%
datos_barrios.query('Barrio in @top_barrios') #@ me ayuda a referir una variable det.
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 5              2070.61             2.96
# 10             1654.36             2.68
# 22             2853.23             5.03
# 24             2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio', y='Valor_m2_Barrio', data= datos_barrios.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x',rotation =45) #tick_params con rotation det. una inclinacion en el nombre de ref.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data = datos_barrios.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio', y='Precio_Millon', data= datos_barrios.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x',rotation =45) #tick_params con rotation det. una inclinacion en el nombre de ref.
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millones', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millones', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millones < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Area', data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon<2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()
